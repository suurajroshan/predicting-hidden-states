# %%
import wandb
api = wandb.Api()

# %%
runs = api.runs("hidden-state-predictions/llama-0.1B-gumbel-layers")

for run in runs:
    print(f"Name: {run.name}, ID: {run.id}")
# Out:
# Name: seed-42-layer-3-llf-1e-4, ID: m0rramva
# Name: seed-42-layer-1-llf-1e-4, ID: higg97wk
# Name: seed-44-layer-1-llf-1e-4, ID: kzau6qbx
# Name: seed-44-layer-3-llf-1e-4, ID: 3ff6mzhr
# Name: seed-42-layer-7-llf-1e-4, ID: 6egklfnw
# Name: seed-44-layer-7-llf-1e-4, ID: jq78rw1y
# Name: seed-42-layer-5-llf-1e-4, ID: rlbi8oq6
# Name: seed-44-layer-5-llf-1e-4, ID: gmi7oqoc
# Name: seed-42-layer-11-llf-1e-4, ID: v812uata
# Name: seed-44-layer-11-llf-1e-4, ID: 1919avxo
# Name: seed-40-layer-1-llf-1e-4, ID: xri5eao3
# Name: seed-40-layer-3-llf-1e-4, ID: 4i8p7bkh
# Name: seed-40-layer-11-llf-1e-4, ID: gvj5onuw
# Name: seed-42-layer-11-llf-1e-4, ID: x6ir00xy
# Name: seed-44-layer-11-llf-1e-4, ID: wphoggb1
# Name: seed-40-layer-5-llf-1e-4, ID: 0gqmnhwd
# Name: seed-40-layer-10-llf-1e-4, ID: bbps1lv3
# Name: seed-40-layer-7-llf-1e-4, ID: 7iw4eptq
# Name: seed-42-layer-10-llf-1e-4, ID: bqz8cqrb
# Name: seed-44-layer-10-llf-1e-4, ID: rdm7z74s
# Name: seed-40-layer-9-llf-1e-4, ID: ozmabdnv
# ...
